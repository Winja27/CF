# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv('考题五/考题五/metrics.csv')
ax = sns.barplot(data=df)
ax.set(xlabel='Metrics', ylabel='Values', title='Metrics of Matirx Factorization')
plt.show()
